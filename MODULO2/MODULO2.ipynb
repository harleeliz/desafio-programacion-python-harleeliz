# %% [markdown]
# # Modulo 2
#
# Curso Desafío de Programación en Python LinkedIn
#
# Nombre: Harlee Liz Ramos

# %%
import pandas as pd
import seaborn as sns
# Out:
# Running cells with 'Python 3.9.2' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
df=pd.read_csv('empleados',delimiter=';')
